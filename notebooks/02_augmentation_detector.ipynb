# %%
import os
import json
import cv2
from tqdm import tqdm
import albumentations as A
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import json
#       3 import cv2
# ----> 4 from tqdm import tqdm
#       5 import albumentations as A
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
#Paths
RAW_DIR = "../data/raw"  # adjust if needed
TRAIN_JSON = f"{RAW_DIR}/train/train.json"
VAL_JSON   = f"{RAW_DIR}/val/val.json"

OUT_TRAIN_DIR = "../data/detection/train_aug"
OUT_VAL_DIR   = "../data/detection/val_aug"

os.makedirs(f"{OUT_TRAIN_DIR}/images", exist_ok=True)
os.makedirs(f"{OUT_VAL_DIR}/images", exist_ok=True)
